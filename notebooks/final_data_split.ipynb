# %%
import os
from PIL import Image

# %%
base_dir="/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/pakistan"
#fetch all the folder names
folders = os.listdir(base_dir)
# skip the folder names that are in name "wb_small_airshed,dhaka_airshed"lucknow_airshed,delhi_airshed
# folders = [folder for folder in folders if not folder in ["wb_small_airshed", "dhaka_airshed", "lucknow_airshed", "delhi_airshed","bangladesh","gujarat","sindh",'jarkhand', 'gujarat', 'west_bengal', 'jharkhand', 'punjab', 'bihar', 'rajasthan', 'assam', 'haryana']]
folders=['pak_punjab']
#loop through each folder and fetch all the .png files and check in which folder they are present png are in rgba not rgb format
for folder in folders:
    print(f"Checking folder: {folder}")
    img_path = os.path.join(base_dir, folder,"images")
    print(f"Image path: {img_path}")
    label_path = os.path.join(base_dir, folder,"labels")
    if os.path.isdir(img_path):
        png_files = [f for f in os.listdir(img_path) if f.endswith('.png')]
        label_files = [f for f in os.listdir(label_path) if f.endswith('.txt')]
        print(f"Folder: {folder}, Number of images: {len(png_files)}, Number of labels: {len(label_files)}")
        #Check if there are any images that are in RGBA format not RGB format then print the name of the folder isint Image library able to open the image
        for png_file in png_files:
            img = Image.open(os.path.join(img_path, png_file))
            if img.mode != 'RGB':
                print(f"Image {png_file} in folder {folder} is not in RGB format, it is in {img.mode} format")
            try:
                img.verify()
            except Exception as e:
                print(f"Image {png_file} in folder {folder} is not a valid image, error: {e}")
# Out:
# Checking folder: pak_punjab
# Image path: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/pakistan/pak_punjab/images
# Folder: pak_punjab, Number of images: 12896, Number of labels: 12896

# %%
# import os
# import shutil

# country = "afghanistan"
# state= "afghanistan"
# src_labels = os.path.join(base_dir, state, "labels")
# os.makedirs(src_labels, exist_ok=True)
# assert os.path.exists(src_labels), f"Source labels folder does not exist: {src_labels}"
# dst_labels = os.path.join(base_dir, country, state, "labels")
# os.makedirs(dst_labels, exist_ok=True)
# assert os.path.exists(dst_labels), f"Destination labels folder does not exist: {dst_labels}"
# assert os.path.exists(src_labels), f"Source labels folder does not exist: {src_labels}"
# shutil.copytree(src_labels, dst_labels, dirs_exist_ok=True)

# # Step 3: Copy matching images from 'rgb' folder based on label file names
# rgb_folder = os.path.join(base_dir, state, "rgb")
# image_dst = os.path.join(base_dir, country,state, "images")
# os.makedirs(image_dst, exist_ok=True)
# assert os.path.exists(rgb_folder), f"RGB folder does not exist: {rgb_folder}"
# assert os.path.exists(image_dst), f"Destination image folder does not exist: {image_dst}"

# # Get label file names (without extension)
# label_filenames = [os.path.splitext(f)[0] for f in os.listdir(dst_labels) if f.endswith('.txt')]

# # Copy corresponding image if it exists
# for name in label_filenames:
#     for ext in ['.jpg', '.jpeg', '.png', '.tif']:  # try multiple possible extensions
#         image_path = os.path.join(rgb_folder, name + ext)
#         if os.path.exists(image_path):
#             shutil.copy(image_path, image_dst)
#             print(f"✅ Copied {name+ext}")
#             break
#     else:
#         print(f"❌ No matching image found for label: {name}")
# Out:
# ✅ Copied 36.7206_67.0106.png
# ✅ Copied 36.8058_70.0370.png
# ✅ Copied 36.0970_68.5958.png
# ✅ Copied 36.6382_68.8992.png
# ✅ Copied 34.2383_62.4282.png
# ✅ Copied 34.6173_69.2492.png
# ✅ Copied 33.3470_69.9370.png
# ✅ Copied 36.5794_65.7870.png
# ✅ Copied 36.6970_69.5106.png
# ✅ Copied 34.4382_70.3106.png
# ✅ Copied 36.8970_66.1459.png
# ✅ Copied 31.5558_65.7106.png
# ✅ Copied 31.5672_65.6694.png
# ✅ Copied 33.5206_69.1370.png
# ✅ Copied 36.7172_67.2195.png
# ✅ Copied 35.8294_68.7958.png
# ✅ Copied 33.4794_68.4695.png
# ✅ Copied 36.4970_65.7992.png
# ✅ Copied 34.6558_69.2958.png
# ✅ Copied 33.4672_68.5106.png
# ✅ Copied 36.9970_67.0194.png
# ✅ Copied 31.5794_64.4458.png
# ✅ Copied 34.4206_70.2992.png
# ✅ Copied 35.7172_64.2194.png
# ✅ Copied 37.1558_68.8606.png
# ✅ Copied 37.1706_70.5106.png
# ✅ Copied 33.3206_69.8371.png
# ✅ Copied 34.7706_69.1958.png
# ✅ Copied 36.2794_68.7992.png
# ✅ Copied 36.6558_65.8194.png
# ✅ Copied 36.3470_64.8871.png
# ✅ Copied 36.0470_68.6782.png
# ...

# %%
# output_dir = os.path.join(base_dir, "stratified_split_domain_adaptation","", "labels")
# os.makedirs(output_dir, exist_ok=True)

# assert os.path.exists(output_dir), f"Output directory does not exist: {output_dir}"

# # Folders to recursively search for images
# image_dirs = [
#     os.path.join(base_dir, "pakistan"),
#     os.path.join(base_dir, "india"),
#     os.path.join(base_dir, "Bangladesh", "labels")
# ]

# image_extensions = ('.txt')

# for image_dir in image_dirs:
#     for root, _, files in os.walk(image_dir):
#         for file in files:
#             if file.lower().endswith(image_extensions):
#                 src_path = os.path.join(root, file)
#                 dst_path = os.path.join(output_dir, file)

#                 # Optional: rename file if a duplicate name exists
#                 if os.path.exists(dst_path):
#                     # Prefix with parent folder to avoid overwrite
#                     prefix = os.path.basename(os.path.dirname(src_path))
#                     file_root, ext = os.path.splitext(file)
#                     dst_path = os.path.join(output_dir, f"{prefix}_{file_root}{ext}")

#                 shutil.copy(src_path, dst_path)
#                 print(f"✅ Copied: {src_path} → {dst_path}")

# %%
## OBB->aa
import os
import glob

# Constants
IMG_WIDTH = 128
IMG_HEIGHT = 128

# Paths
base_label_path = "/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/labels"
aa_label_path = os.path.join(os.path.dirname(base_label_path), "aa_labels")
print(f"Base label path: {base_label_path}")
print(f"AA label path: {aa_label_path}")
os.makedirs(aa_label_path, exist_ok=True)

def convert_obb_to_aabb(coords):
    xs = coords[::2]
    ys = coords[1::2]
    x_min, x_max = min(xs), max(xs)
    y_min, y_max = min(ys), max(ys)

    x_center = (x_min + x_max) / 2.0
    y_center = (y_min + y_max) / 2.0
    width = x_max - x_min
    height = y_max - y_min

    if width < 0 or height < 0:
        raise ValueError("Width and height must be positive values.")

    return [x_center, y_center, width, height]

# Process each label file
label_files = glob.glob(os.path.join(base_label_path, "*.txt"))

for label_file in label_files:
    with open(label_file, 'r') as f:
        lines = f.readlines()

    new_lines = []
    for line in lines:
        parts = line.strip().split()
        if len(parts) != 9:
            print(f"Skipping malformed line in {label_file}: {line}")
            continue
        class_id = parts[0]
        coords = list(map(float, parts[1:]))
        try:
            xc, yc, w, h = convert_obb_to_aabb(coords)
        except Exception as e:
            print(f"Error in {label_file}: {e}")
            continue

        new_lines.append(f"{class_id} {xc:.6f} {yc:.6f} {w:.6f} {h:.6f}")

    # Write to new file
    out_path = os.path.join(aa_label_path, os.path.basename(label_file))
    with open(out_path, 'w') as out_f:
        out_f.write('\n'.join(new_lines))

print(f"✅ Converted {len(label_files)} files and saved to: {aa_label_path}")
# Out:
# Base label path: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/labels
# AA label path: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/aa_labels
# ✅ Converted 743 files and saved to: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/aa_labels

# %%
## OBB -> DOTA Format
import os
from tqdm import tqdm

# Mapping from class ID to class name
class_mapping = {0: "CFCBK", 1: "FCBK", 2: "Zigzag"}

def convert_to_dota_format(input_path, output_path, image_width, image_height):
    """
    Convert a single label file from normalized format (YOLO-OBB style)
    to DOTA format.
    """
    with open(input_path, "r") as infile, open(output_path, "w") as outfile:
        for line in infile:
            values = line.strip().split()
            if len(values) < 9:
                continue  # Skip incomplete lines

            class_id = int(values[0])
            coordinates = list(map(float, values[1:9]))

            # Denormalize coordinates
            denormalized_coords = [
                round(coordinates[i] * (image_width if i % 2 == 0 else image_height), 2)
                for i in range(8)
            ]

            class_name = class_mapping.get(class_id, "UNKNOWN")
            # Format: x1 y1 x2 y2 x3 y3 x4 y4 class_name difficult
            dota_line = " ".join(map(str, denormalized_coords)) + f" {class_name} 0\n"
            outfile.write(dota_line)

def process_folder(input_folder, output_folder, image_width, image_height):
    """
    Process all `.txt` label files in the input folder and convert to DOTA format.
    """
    if not os.path.exists(input_folder):
        raise FileNotFoundError(f"Input folder '{input_folder}' not found")
    
    os.makedirs(output_folder, exist_ok=True)
    label_files = sorted([f for f in os.listdir(input_folder) if f.endswith(".txt")])

    for file_name in tqdm(label_files, desc="Converting to DOTA format", unit="file"):
        input_path = os.path.join(input_folder, file_name)
        output_path = os.path.join(output_folder, file_name)
        convert_to_dota_format(input_path, output_path, image_width, image_height)

# === Main Call ===
if __name__ == "__main__":
    input_folder = "/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/labels"
    output_folder = os.path.join(os.path.dirname(input_folder), "dota_labels")
    image_width = 128
    image_height = 128

    process_folder(input_folder, output_folder, image_width, image_height)

    print(f"\n✅ All label files converted and saved to: {output_folder}")
# Out:
# Converting to DOTA format: 100%|██████████| 743/743 [00:00<00:00, 14893.11file/s]
# ✅ All label files converted and saved to: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/dota_labels

# %%
#OBB -> COCO Format
import os
import json
import glob

IMG_WIDTH = 128
IMG_HEIGHT = 128

# Path configuration
image_dir = "/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/images"
label_dir = "/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/labels"
output_json = "/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/labels.json"

# Category info
class_mapping = {0: "CFCBK", 1: "FCBK", 2: "Zigzag"}
categories = [{"id": k, "name": v, "supercategory": "kiln"} for k, v in class_mapping.items()]

images = []
annotations = []
ann_id = 1  # Annotation ID starts at 1

label_files = sorted(glob.glob(os.path.join(label_dir, "*.txt")))

for img_id, label_path in enumerate(label_files, 1):
    base_name = os.path.splitext(os.path.basename(label_path))[0]
    image_filename = base_name + ".png"
    image_path = os.path.join(image_dir, image_filename)

    # Register image info
    images.append({
        "id": img_id,
        "file_name": image_filename,
        "width": IMG_WIDTH,
        "height": IMG_HEIGHT
    })

    # Read and convert each label line
    with open(label_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) != 9:
                continue  # skip invalid lines
            class_id = int(parts[0])
            coords = list(map(float, parts[1:9]))

            # Denormalize polygon
            poly = [
                round(coords[i] * (IMG_WIDTH if i % 2 == 0 else IMG_HEIGHT), 2)
                for i in range(8)
            ]

            # Bounding box from polygon (xmin, ymin, width, height)
            xs = poly[0::2]
            ys = poly[1::2]
            xmin = min(xs)
            xmax = max(xs)
            ymin = min(ys)
            ymax = max(ys)
            width = xmax - xmin
            height = ymax - ymin

            # COCO annotation
            annotations.append({
                "id": ann_id,
                "image_id": img_id,
                "category_id": class_id,
                "bbox": [xmin, ymin, width, height],
                "area": round(width * height, 2),
                "segmentation": [poly],
                "iscrowd": 0
            })
            ann_id += 1

# Final COCO structure
coco_dict = {
    "images": images,
    "annotations": annotations,
    "categories": categories
}

# Save to JSON
with open(output_json, "w") as f:
    json.dump(coco_dict, f, indent=4)

print(f"\n✅ COCO-format annotations saved to: {output_json}")
# Out:
# ✅ COCO-format annotations saved to: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/labels.json

# %%
import os
import shutil
import json
from sklearn.model_selection import StratifiedShuffleSplit
from collections import Counter

# ==== Base paths ====
base_path = "/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan"
images_path = os.path.join(base_path, "images")
labels_path = os.path.join(base_path, "labels")
aa_labels_path = os.path.join(base_path, "aa_labels")
dota_labels_path = os.path.join(base_path, "dota_labels")
coco_path = os.path.join(base_path, "labels.json")

# ==== Output split directories ====
splits = ['train', 'val', 'test']
for split in splits:
    os.makedirs(os.path.join(base_path, split, "images"), exist_ok=True)
    os.makedirs(os.path.join(base_path, split, "labels"), exist_ok=True)
    os.makedirs(os.path.join(base_path, split, "aa_labels"), exist_ok=True)
    os.makedirs(os.path.join(base_path, split, "dota_labels"), exist_ok=True)

# ==== Step 1: Collect image file names and dominant class ====
image_files = []
class_ids = []

for label_file in os.listdir(labels_path):
    if not label_file.endswith('.txt'):
        continue

    label_fp = os.path.join(labels_path, label_file)
    try:
        with open(label_fp, 'r') as f:
            lines = f.readlines()
            if not lines:
                continue
            labels = [int(line.strip().split()[0]) for line in lines]
            most_common_class = Counter(labels).most_common(1)[0][0]
            image_name = os.path.splitext(label_file)[0] + ".png"
            if os.path.exists(os.path.join(images_path, image_name)):
                image_files.append(os.path.splitext(label_file)[0])
                class_ids.append(most_common_class)
    except Exception as e:
        print(f"⚠️ Error reading {label_file}: {e}")

# ==== Step 1.5: Filter classes with fewer than 2 samples ====
class_count = Counter(class_ids)
filtered_image_files = []
filtered_class_ids = []

for img, cls in zip(image_files, class_ids):
    if class_count[cls] > 1:
        filtered_image_files.append(img)
        filtered_class_ids.append(cls)

print(f"⚠️ Removed {len(image_files) - len(filtered_image_files)} images with rare classes")

image_files = filtered_image_files
class_ids = filtered_class_ids

# ==== Step 2: Stratified split (60:20:20) ====
splitter1 = StratifiedShuffleSplit(n_splits=1, test_size=0.4, random_state=42)
train_idx, temp_idx = next(splitter1.split(image_files, class_ids))

train_files = [image_files[i] for i in train_idx]
train_classes = [class_ids[i] for i in train_idx]

temp_files = [image_files[i] for i in temp_idx]
temp_classes = [class_ids[i] for i in temp_idx]

# ==== Step 2.5: Filter temp_files to remove classes with <2 samples ====
temp_class_counts = Counter(temp_classes)
filtered_temp_files = []
filtered_temp_classes = []

for f, c in zip(temp_files, temp_classes):
    if temp_class_counts[c] > 1:
        filtered_temp_files.append(f)
        filtered_temp_classes.append(c)

print(f"⚠️ Removed {len(temp_files) - len(filtered_temp_files)} temp files with rare classes")

# ==== Step 2.6: Stratified split of temp into val and test ====
splitter2 = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=42)
val_idx, test_idx = next(splitter2.split(filtered_temp_files, filtered_temp_classes))

val_files = [filtered_temp_files[i] for i in val_idx]
test_files = [filtered_temp_files[i] for i in test_idx]

# ==== Step 3: Copy files ====
def copy_all_formats(files, split):
    for file in files:
        for ext in ['.jpg', '.png']:
            src_img = os.path.join(images_path, file + ext)
            if os.path.exists(src_img):
                break
        else:
            print(f"⚠️ Image file missing for {file}")
            continue

        # Copy image
        shutil.copy(src_img, os.path.join(base_path, split, "images", os.path.basename(src_img)))

        # Copy label formats
        for lbl_dir, subfolder in [
            (labels_path, "labels"),
            (aa_labels_path, "aa_labels"),
            (dota_labels_path, "dota_format_labels"),
        ]:
            src_lbl = os.path.join(lbl_dir, file + ".txt")
            dst_lbl = os.path.join(base_path, split, subfolder, file + ".txt")
            if os.path.exists(src_lbl):
                shutil.copy(src_lbl, dst_lbl)
            else:
                print(f"⚠️ Missing {subfolder} for {file}")

copy_all_formats(train_files, "train")
copy_all_formats(val_files, "val")
copy_all_formats(test_files, "test")

# ==== Step 4: Split COCO format JSON ====
with open(coco_path, "r") as f:
    coco_data = json.load(f)

filename_to_split = {
    fname + ".png": split
    for split, files in zip(["train", "val", "test"], [train_files, val_files, test_files])
    for fname in files
}

split_coco = {"train": [], "val": [], "test": []}
image_id_to_split = {}

# Split images
for image in coco_data["images"]:
    split = filename_to_split.get(image["file_name"])
    if split:
        image_id_to_split[image["id"]] = split
        split_coco[split].append(image)

# Split annotations
annotations_by_split = {"train": [], "val": [], "test": []}
for ann in coco_data["annotations"]:
    split = image_id_to_split.get(ann["image_id"])
    if split:
        annotations_by_split[split].append(ann)

# Save split JSON files
for split in ["train", "val", "test"]:
    output_json = {
        "images": split_coco[split],
        "annotations": annotations_by_split[split],
        "categories": coco_data["categories"]
    }
    out_path = os.path.join(base_path, f"coco_{split}.json")
    with open(out_path, "w") as f:
        json.dump(output_json, f, indent=4)
    print(f"✅ COCO {split} saved: {out_path}")

# ==== Final Summary ====
print(f"\n✅ Stratified split complete:")
print(f"  Train: {len(train_files)}")
print(f"  Val:   {len(val_files)}")
print(f"  Test:  {len(test_files)}")
# Out:
# ⚠️ Removed 1 images with rare classes
# ⚠️ Removed 1 temp files with rare classes
# ✅ COCO train saved: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/coco_train.json
# ✅ COCO val saved: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/coco_val.json
# ✅ COCO test saved: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/coco_test.json
#
# ✅ Stratified split complete:
#   Train: 445
#   Val:   148
#   Test:  148

# %%
def count_classes_in_split(split_dir):
    label_dir = os.path.join(base_path, split_dir, "labels")
    class_counter = Counter()

    for label_file in os.listdir(label_dir):
        if not label_file.endswith(".txt"):
            continue
        label_path = os.path.join(label_dir, label_file)
        with open(label_path, "r") as f:
            for line in f:
                parts = line.strip().split()
                if parts:
                    class_id = int(parts[0])
                    class_counter[class_id] += 1
    return class_counter

print("\n📊 Class distribution per split:")
for split in ["train", "val", "test"]:
    counter = count_classes_in_split(split)
    print(f"  {split.capitalize()}:")
    for cls, count in sorted(counter.items()):
        print(f"    Class {cls}: {count}")
# Out:
# 📊 Class distribution per split:
#   Train:
#     Class 1: 590
#     Class 2: 2
#   Val:
#     Class 1: 204
#   Test:
#     Class 1: 204

# %%
import os
import shutil

# Define paths
AFG_TRAIN = "/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/afghanistan/afghanistan/test"
FULL_TRAIN = "/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/stratified_split/test"
FINAL_TRAIN = "/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/final_data_neurips_2025/test"

# Create final output directories
os.makedirs(os.path.join(FINAL_TRAIN, "images"), exist_ok=True)
os.makedirs(os.path.join(FINAL_TRAIN, "labels"), exist_ok=True)
os.makedirs(os.path.join(FINAL_TRAIN, "aa_labels"), exist_ok=True)
os.makedirs(os.path.join(FINAL_TRAIN, "dota_format_labels"), exist_ok=True)

# Function to copy files
def copy_files(source_dir, target_dir):
    for file in os.listdir(source_dir):
        source_file = os.path.join(source_dir, file)
        target_file = os.path.join(target_dir, file)
        if os.path.isdir(source_file):
            shutil.copytree(source_file, target_file)
        else:
            shutil.copy2(source_file, target_file)

# Copy data from FULL_TRAIN
copy_files(os.path.join(FULL_TRAIN, "images"), os.path.join(FINAL_TRAIN, "images"))
copy_files(os.path.join(FULL_TRAIN, "labels"), os.path.join(FINAL_TRAIN, "labels"))
copy_files(os.path.join(FULL_TRAIN, "aa_labels"), os.path.join(FINAL_TRAIN, "aa_labels"))
copy_files(os.path.join(FULL_TRAIN, "dota_format_labels"), os.path.join(FINAL_TRAIN, "dota_format_labels"))

# Copy data from AFG_TRAIN
copy_files(os.path.join(AFG_TRAIN, "images"), os.path.join(FINAL_TRAIN, "images"))
copy_files(os.path.join(AFG_TRAIN, "labels"), os.path.join(FINAL_TRAIN, "labels"))
copy_files(os.path.join(AFG_TRAIN, "aa_labels"), os.path.join(FINAL_TRAIN, "aa_labels"))
copy_files(os.path.join(AFG_TRAIN, "dota_format_labels"), os.path.join(FINAL_TRAIN, "dota_format_labels"))

print("✅ Data successfully copied to the final directory.")
# Out:
# ✅ Data successfully copied to the final directory.

# %%
import os

# Define the merged final directory
FINAL_TRAIN = "/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/data/processed_data/sentinel/final_data_neurips_2025/test"

# Subdirectories to count files
subdirectories = ["images", "labels", "aa_labels", "dota_format_labels"]

# Function to count the files in each subdirectory
def count_files_in_subdirectories(base_path, subdirectories):
    file_counts = {}
    for subdir in subdirectories:
        subdir_path = os.path.join(base_path, subdir)
        if os.path.exists(subdir_path):
            file_counts[subdir] = len(os.listdir(subdir_path))
        else:
            file_counts[subdir] = 0
    return file_counts

# Get the file counts after merging
file_counts = count_files_in_subdirectories(FINAL_TRAIN, subdirectories)

# Print the file counts
for subdir, count in file_counts.items():
    print(f"Number of files in {subdir}: {count}")
# Out:
# Number of files in images: 15738
# Number of files in labels: 15738
# Number of files in aa_labels: 15738
# Number of files in dota_format_labels: 15738
