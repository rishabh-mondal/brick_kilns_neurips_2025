# %%
import os
import ee
import geemap
import requests
import leafmap
import numpy as np
import pandas as pd
import geopandas as gpd
import concurrent.futures
import matplotlib.pyplot as plt
from shapely.geometry import box  
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
import concurrent.futures
import ee
import requests
from tqdm import tqdm

import os
import requests
import ee
import rasterio
from rasterio.errors import RasterioIOError
from tqdm import tqdm

# %%
region="balochistan"
save_path=f"/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/{region}"
os.makedirs(save_path, exist_ok=True)
# data_path = f"/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/regions/shapes/{region}.geojson"

# gdf=gpd.read_file(data_path)
# gdf_projected = gdf.to_crs(epsg=32643)
# gdf['area_m2'] = gdf_projected.area
# gdf['area_km2'] = gdf['area_m2'] / (1000**2)
# print(f"Area in square meters: {gdf['area_m2'].iloc[0]:,.2f} m²")
# print(f"Area in square kilometers: {gdf['area_km2'].iloc[0]:,.2f} km²")


# # bounds of the AOI (minx, miny, maxx, maxy)
# minx, miny, maxx, maxy = gdf.total_bounds
# grid_size = 0.05  # Tile size in degrees
# lons = np.arange(minx, maxx, grid_size)
# lats = np.arange(miny, maxy, grid_size)
# tiles = []
# center_coords = []
# for lon in lons:
#     for lat in lats:
#         tile_geometry = box(lon, lat, lon + grid_size, lat + grid_size)
#         tile = gpd.GeoDataFrame({'geometry': [tile_geometry]}, crs='EPSG:4326')
#         tiles.append(tile)
#         center_lon = lon + grid_size / 2
#         center_lat = lat + grid_size / 2
#         center_coords.append((center_lon, center_lat))

# tiles_gdf = gpd.GeoDataFrame(pd.concat(tiles, ignore_index=True), crs='EPSG:4326')
# tiles_gdf['center_coordinates'] = center_coords





# # Create tiles
# tiles = []
# tiles_names = []
# center_coords = []

# for lon in lons:
#     for lat in lats:
#         tile_geometry = box(lon, lat, lon + grid_size, lat + grid_size)
#         tile = gpd.GeoDataFrame({'geometry': [tile_geometry]}, crs='EPSG:4326')
#         tiles.append(tile)

#         # Create tile name and center coordinates
#         tile_name = f"Tile_{lon:.4f}_{lat:.4f}"
#         tiles_names.append(tile_name)

#         center_lon = lon + grid_size / 2
#         center_lat = lat + grid_size / 2
#         center_coords.append((center_lon, center_lat))

# print(f"Generated {len(tiles)} tiles.")

# # Combine into a single GeoDataFrame
# tiles_gdf = gpd.GeoDataFrame(pd.concat(tiles, ignore_index=True), crs='EPSG:4326')
# tiles_gdf['tile_name'] = tiles_names
# tiles_gdf['center_coordinates'] = center_coords
# tiles_gdf['area_m2'] = tiles_gdf.geometry.area

# # Area of AOI
# aoi_area = gdf.area.sum()
# print(f"Area of AOI: {aoi_area:.2f} square meters")

# # Extract tile center and corners
# def extract_tile_details(gdf):
#     tile_details = []
#     for _, row in gdf.iterrows():
#         bounds = row.geometry.bounds
#         center_x = (bounds[0] + bounds[2]) / 2
#         center_y = (bounds[1] + bounds[3]) / 2
#         corners = {
#             'top_left': (bounds[0], bounds[3]),
#             'top_right': (bounds[2], bounds[3]),
#             'bottom_left': (bounds[0], bounds[1]),
#             'bottom_right': (bounds[2], bounds[1])
#         }
#         tile_details.append({
#             'tile_name': row.tile_name,
#             'center_coordinates': (center_x, center_y),
#             'corner_coordinates': corners
#         })
#     return tile_details

# tile_details_df = pd.DataFrame(extract_tile_details(tiles_gdf))

# # print(tile_details_df)

# # Sentinel-2 band info
# sentinel2_bands = {
#     "B2": {"name": "Blue", "resolution": 10, "central_wavelength": 490},
#     "B3": {"name": "Green", "resolution": 10, "central_wavelength": 560},
#     "B4": {"name": "Red", "resolution": 10, "central_wavelength": 665},
#     # "B8": {"name": "NIR", "resolution": 10, "central_wavelength": 842},
#     # "B11": {"name": "SWIR1", "resolution": 20, "central_wavelength": 1610},
#     # "B12": {"name": "SWIR2", "resolution": 20, "central_wavelength": 2190},
# }

# # Add band info to tiles
# for band_name, band_info in sentinel2_bands.items():
#     tile_details_df[f"{band_name}_resolution"] = band_info['resolution']
#     tile_details_df[f"{band_name}_central_wavelength"] = band_info['central_wavelength']

# # Intersection and filtering
# tiles_gdf['intersection_area'] = tiles_gdf.intersection(gdf.unary_union).area
# threshold_area = 0.015 * grid_size * grid_size
# filtered_tiles_gdf = tiles_gdf[tiles_gdf['intersection_area'] > threshold_area]
# print(f"Filtered {len(filtered_tiles_gdf)} tiles based on intersection area.")

# # print(f"Filtered tiles: {filtered_tiles_gdf[['tile_name', 'intersection_area']]}")

# # Extract tile details again for filtered tiles
# filtered_tile_details_df = pd.DataFrame(extract_tile_details(filtered_tiles_gdf))

# # Add band info again
# for band_name, band_info in sentinel2_bands.items():
#     filtered_tile_details_df[f"{band_name}_resolution"] = band_info['resolution']
#     filtered_tile_details_df[f"{band_name}_central_wavelength"] = band_info['central_wavelength']

# # Merge filtered tile details with filtered tiles_gdf
# filtered_tiles_gdf['tile_details'] = filtered_tile_details_df.apply(lambda row: {
#     'tile_name': row.tile_name,
#     'center_coordinates': row.center_coordinates,
#     'corner_coordinates': row.corner_coordinates,
#     'B2_resolution': row.B2_resolution,
#     'B2_central_wavelength': row.B2_central_wavelength,
#     'B3_resolution': row.B3_resolution,
#     'B3_central_wavelength': row.B3_central_wavelength,
#     'B4_resolution': row.B4_resolution,
#     'B4_central_wavelength': row.B4_central_wavelength,
#     # 'B8_resolution': row.B8_resolution,
#     # 'B8_central_wavelength': row.B8_central_wavelength,
#     # 'B11_resolution': row.B11_resolution,
#     # 'B11_central_wavelength': row.B11_central_wavelength,
#     # 'B12_resolution': row.B12_resolution,
#     # 'B12_central_wavelength': row.B12_central_wavelength
# }, axis=1)

filtered_tiles_path=f"/home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/sentinel_metadata/{region}_missing_tiles.geojson"
# Stats
filtered_tiles_gdf = gpd.read_file(filtered_tiles_path)

num_tiles = len(filtered_tiles_gdf)
average_file_size_mb = 1.80
total_file_size_mb = num_tiles * average_file_size_mb
total_memory_gb = total_file_size_mb / 1024

print(f"Total number of filtered tiles: {num_tiles}")
print(f"Estimated total file size: {total_file_size_mb:.2f} MB")
print(f"Estimated total memory required: {total_memory_gb:.2f} GB")

import ee

ee.Initialize()

# Function to mask clouds
def mask_clouds(image):
    qa = image.select('QA60').uint16()  # Ensure it's an integer
    cloud_mask = qa.bitwiseAnd(1 << 10).eq(0)  # Identify non-cloud pixels
    return image.updateMask(cloud_mask)

# Function to download a single tile
def download_tile(tile_geometry, tile_name, save_path):
    try:
        ee_tile = ee.Geometry.Polygon(list(tile_geometry.exterior.coords))

        # Get the best available image
        image_collection = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED") \
            .filterBounds(ee_tile) \
            .filterDate('2024-01-01', '2025-02-28') \
            .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 1)) \
            .select(['B4', 'B3', 'B2', 'QA60']) \
            .sort('CLOUDY_PIXEL_PERCENTAGE')

        # Try the least cloudy image first
        best_image = image_collection.first().clip(ee_tile)
        best_image = mask_clouds(best_image)

        # Use median image as backup
        backup_image = image_collection.median().clip(ee_tile)
        backup_image = mask_clouds(backup_image)

        # Compute valid pixel counts
        valid_pixels_best = ee.Number(best_image.reduceRegion(
            reducer=ee.Reducer.count(),
            geometry=ee_tile,
            scale=10
        ).values().get(0))

        valid_pixels_backup = ee.Number(backup_image.reduceRegion(
            reducer=ee.Reducer.count(),
            geometry=ee_tile,
            scale=10
        ).values().get(0))

        # Select the image with more valid pixels
        final_image = ee.Algorithms.If(valid_pixels_best.gt(valid_pixels_backup), best_image, backup_image)

        # Generate download URL
        url = ee.Image(final_image).getDownloadURL({
            'scale': 10,
            'region': ee_tile.getInfo(),
            'format': 'GEO_TIFF'
        })

        # Download the image
        response = requests.get(url)
        with open(f'{save_path}/{tile_name}.tif', 'wb') as f:
            f.write(response.content)

        print(f"Downloaded {tile_name}")

    except Exception as e:
        print(f"Skipping {tile_name}: {str(e)}")

# Function to check if a downloaded .tif file is valid
def check_tif_file(file_path, min_size_mb=1):
    """Check if the downloaded .tif file exists, is not empty, and is a valid GeoTIFF."""
    if not os.path.exists(file_path):
        return False

    # Check if the file size is greater than a reasonable threshold (e.g., 1 MB)
    if os.path.getsize(file_path) < min_size_mb * 1024 * 1024:  # 1 MB threshold
        print(f"File is too small: {file_path}")
        return False

    # Check if the file is a valid GeoTIFF using rasterio
    try:
        with rasterio.open(file_path) as ds:
            if ds.count < 1:
                print(f"Invalid raster (no bands): {file_path}")
                return False
        return True
    except rasterio.errors.RasterioIOError:
        print(f"Invalid GeoTIFF file: {file_path}")
        return False

# Function to handle download and validation sequentially
def download_and_validate_tile(tile_geometry, tile_name, save_path):
    try:
        ee.Initialize()  # Ensure Earth Engine is initialized in this subprocess
    except Exception as e:
        print(f"GEE initialization failed in subprocess for {tile_name}: {e}")
        return
    
    tile_path = os.path.join(save_path, f'{tile_name}.tif')

    # Download the tile
    download_tile(tile_geometry, tile_name, save_path)
    
    # Check if the downloaded file is valid
    if check_tif_file(tile_path):
        print(f"Tile {tile_name} is valid.")
    else:
        print(f"Tile {tile_name} is invalid, re-downloading...")
        download_tile(tile_geometry, tile_name, save_path)
        if check_tif_file(tile_path):
            print(f"Tile {tile_name} re-downloaded and is now valid.")
        else:
            print(f"Tile {tile_name} is still invalid after re-downloading.")

    
# Function to process all tiles sequentially
# def process_tiles_sequentially(filtered_tiles_gdf, save_path):
#     for _, row in filtered_tiles_gdf.iterrows():
#         tile_geometry = row.geometry
#         tile_name = row.tile_name
        
#         download_and_validate_tile(tile_geometry, tile_name, save_path)

from joblib import Parallel, delayed

def process_tiles_parallel(filtered_tiles_gdf, save_path, n_jobs=4):
    Parallel(n_jobs=n_jobs)(
        delayed(download_and_validate_tile)(
            row.geometry, row.tile_name, save_path
        ) for _, row in filtered_tiles_gdf.iterrows()
    )
process_tiles_parallel(filtered_tiles_gdf, save_path, n_jobs=16)

print("All tiles processed.")       
# Run the tile processing
# process_tiles_sequentially(filtered_tiles_gdf, save_path)

tile_dir = save_path
valid_files = []
invalid_files = []

# Iterate through the downloaded files and check their validity
for filename in os.listdir(save_path):
    if filename.endswith('.tif'):
        file_path = os.path.join(save_path, filename)
        if check_tif_file(file_path):
            valid_files.append(filename)
        else:
            invalid_files.append(filename)

print(f"Valid files: {len(valid_files)}")
print(f"Invalid files: {len(invalid_files)}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total number of filtered tiles: 951
# Estimated total file size: 1711.80 MB
# Estimated total memory required: 1.67 GB
# Downloaded Tile_61.2494_29.4410
# Tile Tile_61.2494_29.4410 is valid.
# Downloaded Tile_61.1494_29.6910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.1494_29.6910.tif
# Tile Tile_61.1494_29.6910 is invalid, re-downloading...
# Downloaded Tile_61.0494_29.7910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.0494_29.7910.tif
# Tile Tile_61.0494_29.7910 is invalid, re-downloading...
# Downloaded Tile_61.1994_29.6410
# Tile Tile_61.1994_29.6410 is valid.
# Downloaded Tile_61.1994_29.5410
# Tile Tile_61.1994_29.5410 is valid.
# Downloaded Tile_61.1494_29.6910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.1494_29.6910.tif
# Tile Tile_61.1494_29.6910 is still invalid after re-downloading.
# Downloaded Tile_61.1494_29.5910
# Tile Tile_61.1494_29.5910 is valid.
# Downloaded Tile_61.0494_29.6410
# Tile Tile_61.0494_29.6410 is valid.
# Downloaded Tile_61.1994_29.6910
# Tile Tile_61.1994_29.6910 is valid.
# Downloaded Tile_61.2994_29.4410
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.2994_29.4410.tif
# Tile Tile_61.2994_29.4410 is invalid, re-downloading...
# Downloaded Tile_61.1994_29.7410
# Tile Tile_61.1994_29.7410 is valid.
# Downloaded Tile_61.2494_29.4910
# Tile Tile_61.2494_29.4910 is valid.
# Downloaded Tile_61.2494_29.5410
# Tile Tile_61.2494_29.5410 is valid.
# Downloaded Tile_61.2994_29.6910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.2994_29.6910.tif
# Tile Tile_61.2994_29.6910 is invalid, re-downloading...
# Downloaded Tile_61.0994_29.5910
# Tile Tile_61.0994_29.5910 is valid.
# Downloaded Tile_61.1994_29.4410
# Tile Tile_61.1994_29.4410 is valid.
# Downloaded Tile_61.3494_29.4910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.3494_29.4910.tif
# Tile Tile_61.3494_29.4910 is invalid, re-downloading...
# Downloaded Tile_61.2994_29.6410
# Tile Tile_61.2994_29.6410 is valid.
# Downloaded Tile_61.2994_29.5910
# Tile Tile_61.2994_29.5910 is valid.
# Downloaded Tile_61.3494_29.4910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.3494_29.4910.tif
# Tile Tile_61.3494_29.4910 is still invalid after re-downloading.
# Downloaded Tile_61.2994_29.4410
# Tile Tile_61.2994_29.4410 re-downloaded and is now valid.
# Downloaded Tile_61.3994_29.1410
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.3994_29.1410.tif
# Tile Tile_61.3994_29.1410 is invalid, re-downloading...
# Downloaded Tile_61.0494_29.7910
# Tile Tile_61.0494_29.7910 re-downloaded and is now valid.
# Downloaded Tile_61.3494_29.1910
# Tile Tile_61.3494_29.1910 is valid.
# Downloaded Tile_61.3994_29.1410
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.3994_29.1410.tif
# Tile Tile_61.3994_29.1410 is still invalid after re-downloading.
# Downloaded Tile_61.3494_29.2910
# Tile Tile_61.3494_29.2910 is valid.
# Downloaded Tile_61.2994_29.6910
# Tile Tile_61.2994_29.6910 re-downloaded and is now valid.
# Downloaded Tile_60.9994_29.6910
# Tile Tile_60.9994_29.6910 is valid.
# Downloaded Tile_61.3994_29.3910
# Tile Tile_61.3994_29.3910 is valid.
# Downloaded Tile_61.3994_29.2410
# Tile Tile_61.3994_29.2410 is valid.
# Downloaded Tile_61.3994_29.4910
# Tile Tile_61.3994_29.4910 is valid.
# Downloaded Tile_60.9494_29.7910
# Tile Tile_60.9494_29.7910 is valid.
# Downloaded Tile_61.3994_29.5910
# Tile Tile_61.3994_29.5910 is valid.
# Downloaded Tile_61.3994_29.5410
# Tile Tile_61.3994_29.5410 is valid.
# Downloaded Tile_60.9494_29.6910
# Tile Tile_60.9494_29.6910 is valid.
# Downloaded Tile_61.4494_29.3410
# Tile Tile_61.4494_29.3410 is valid.
# Downloaded Tile_61.4494_29.5910
# Tile Tile_61.4494_29.5910 is valid.
# Downloaded Tile_61.4494_29.2410
# Tile Tile_61.4494_29.2410 is valid.
# Downloaded Tile_61.3494_29.4410
# Tile Tile_61.3494_29.4410 is valid.
# Downloaded Tile_61.4494_29.5410
# Tile Tile_61.4494_29.5410 is valid.
# Downloaded Tile_61.3994_29.6910
# Tile Tile_61.3994_29.6910 is valid.
# Downloaded Tile_61.4994_28.9410
# Tile Tile_61.4994_28.9410 is valid.
# Downloaded Tile_61.5494_29.1910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.5494_29.1910.tif
# Tile Tile_61.5494_29.1910 is invalid, re-downloading...
# Downloaded Tile_60.8994_29.7410
# Tile Tile_60.8994_29.7410 is valid.
# Downloaded Tile_61.5494_25.1410
# Tile Tile_61.5494_25.1410 is valid.
# Downloaded Tile_61.5994_29.2910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.5994_29.2910.tif
# Tile Tile_61.5994_29.2910 is invalid, re-downloading...
# Downloaded Tile_61.4994_29.0910
# Tile Tile_61.4994_29.0910 is valid.
# Downloaded Tile_61.4994_29.6410
# Tile Tile_61.4994_29.6410 is valid.
# Downloaded Tile_61.5994_29.2910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.5994_29.2910.tif
# Tile Tile_61.5994_29.2910 is still invalid after re-downloading.
# Downloaded Tile_61.5494_28.9410
# Tile Tile_61.5494_28.9410 is valid.
# Downloaded Tile_61.5494_29.0910
# Tile Tile_61.5494_29.0910 is valid.
# Downloaded Tile_61.5994_29.5910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.5994_29.5910.tif
# Tile Tile_61.5994_29.5910 is invalid, re-downloading...
# Downloaded Tile_61.5994_25.1910
# Tile Tile_61.5994_25.1910 is valid.
# Downloaded Tile_61.5994_29.5910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.5994_29.5910.tif
# Tile Tile_61.5994_29.5910 is still invalid after re-downloading.
# Downloaded Tile_61.5494_29.1910
# Downloaded Tile_61.5494_29.2910
# Tile Tile_61.5494_29.1910 re-downloaded and is now valid.
# Tile Tile_61.5494_29.2910 is valid.
# Downloaded Tile_61.5494_29.3910
# Tile Tile_61.5494_29.3910 is valid.
# Downloaded Tile_61.5994_29.1910
# Tile Tile_61.5994_29.1910 is valid.
# Downloaded Tile_61.5994_28.9410
# Tile Tile_61.5994_28.9410 is valid.
# Downloaded Tile_61.5994_25.2410
# Tile Tile_61.5994_25.2410 is valid.
# Downloaded Tile_61.5994_29.3910
# Tile Tile_61.5994_29.3910 is valid.
# Downloaded Tile_61.5994_28.9910
# Tile Tile_61.5994_28.9910 is valid.
# Downloaded Tile_61.5994_28.8410
# Tile Tile_61.5994_28.8410 is valid.
# Downloaded Tile_61.6994_29.0410
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.6994_29.0410.tif
# Tile Tile_61.6994_29.0410 is invalid, re-downloading...
# Downloaded Tile_61.6494_25.7410
# Tile Tile_61.6494_25.7410 is valid.
# Downloaded Tile_61.6494_25.1910
# Tile Tile_61.6494_25.1910 is valid.
# Downloaded Tile_61.6994_24.9910
# Tile Tile_61.6994_24.9910 is valid.
# Downloaded Tile_61.6494_29.3410
# Tile Tile_61.6494_29.3410 is valid.
# Downloaded Tile_61.6494_28.8910
# Tile Tile_61.6494_28.8910 is valid.
# Downloaded Tile_61.6494_28.7910
# Tile Tile_61.6494_28.7910 is valid.
# Downloaded Tile_61.6994_28.6910
# Tile Tile_61.6994_28.6910 is valid.
# Downloaded Tile_61.6994_25.4410
# Tile Tile_61.6994_25.4410 is valid.
# Downloaded Tile_61.6994_25.5410
# Tile Tile_61.6994_25.5410 is valid.
# Downloaded Tile_61.6994_28.9910
# Tile Tile_61.6994_28.9910 is valid.
# Downloaded Tile_61.6994_29.0410
# Tile Tile_61.6994_29.0410 re-downloaded and is now valid.
# Downloaded Tile_61.6994_28.7910
# Tile Tile_61.6994_28.7910 is valid.
# Downloaded Tile_61.6494_25.2410
# Tile Tile_61.6494_25.2410 is valid.
# Downloaded Tile_61.6994_29.2410
# Tile Tile_61.6994_29.2410 is valid.
# Downloaded Tile_61.6994_29.1410
# Tile Tile_61.6994_29.1410 is valid.
# Downloaded Tile_61.6994_29.3910
# Tile Tile_61.6994_29.3910 is valid.
# Downloaded Tile_61.6994_29.4410
# Tile Tile_61.6994_29.4410 is valid.
# Downloaded Tile_61.6994_29.5410
# Tile Tile_61.6994_29.5410 is valid.
# Downloaded Tile_61.6994_29.0910
# Tile Tile_61.6994_29.0910 is valid.
# Downloaded Tile_61.7494_29.2910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.7494_29.2910.tif
# Tile Tile_61.7494_29.2910 is invalid, re-downloading...
# Downloaded Tile_61.7494_25.6410
# Tile Tile_61.7494_25.6410 is valid.
# Downloaded Tile_61.7494_25.4410
# Tile Tile_61.7494_25.4410 is valid.
# Downloaded Tile_61.7494_25.4910
# Tile Tile_61.7494_25.4910 is valid.
# Downloaded Tile_61.6994_29.4910
# Tile Tile_61.6994_29.4910 is valid.
# Downloaded Tile_61.7494_25.2910
# Tile Tile_61.7494_25.2910 is valid.
# Downloaded Tile_61.7494_25.6910
# Tile Tile_61.7494_25.6910 is valid.
# Downloaded Tile_61.7494_29.4910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.7494_29.4910.tif
# Tile Tile_61.7494_29.4910 is invalid, re-downloading...
# Downloaded Tile_61.7494_29.0910
# Tile Tile_61.7494_29.0910 is valid.
# Downloaded Tile_61.7494_29.4910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.7494_29.4910.tif
# Tile Tile_61.7494_29.4910 is still invalid after re-downloading.
# Downloaded Tile_61.7494_28.7410
# Tile Tile_61.7494_28.7410 is valid.
# Downloaded Tile_61.7494_28.9910
# Tile Tile_61.7494_28.9910 is valid.
# Downloaded Tile_61.7994_28.5910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.7994_28.5910.tif
# Tile Tile_61.7994_28.5910 is invalid, re-downloading...
# Downloaded Tile_61.7494_29.2410
# Tile Tile_61.7494_29.2410 is valid.
# Downloaded Tile_61.7994_26.1910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.7994_26.1910.tif
# Tile Tile_61.7994_26.1910 is invalid, re-downloading...
# Downloaded Tile_61.7494_29.4410
# Tile Tile_61.7494_29.4410 is valid.
# Downloaded Tile_61.7994_25.0410
# Tile Tile_61.7994_25.0410 is valid.
# Downloaded Tile_61.7494_29.2910
# Tile Tile_61.7494_29.2910 re-downloaded and is now valid.
# Downloaded Tile_61.7494_29.3910
# Tile Tile_61.7494_29.3910 is valid.
# Downloaded Tile_61.7994_25.0910
# Tile Tile_61.7994_25.0910 is valid.
# Downloaded Tile_61.7994_25.6410
# Tile Tile_61.7994_25.6410 is valid.
# Downloaded Tile_61.7994_25.9410
# Tile Tile_61.7994_25.9410 is valid.
# Downloaded Tile_61.7994_29.2410
# Tile Tile_61.7994_29.2410 is valid.
# Downloaded Tile_61.8494_25.1910
# Tile Tile_61.8494_25.1910 is valid.
# Downloaded Tile_61.7994_28.6410
# Tile Tile_61.7994_28.6410 is valid.
# Downloaded Tile_61.7994_28.7910
# Tile Tile_61.7994_28.7910 is valid.
# Downloaded Tile_61.7994_28.5910
# Tile Tile_61.7994_28.5910 re-downloaded and is now valid.
# Downloaded Tile_61.7994_29.3910
# Downloaded Tile_61.7994_26.1910
# Tile Tile_61.7994_29.3910 is valid.
# Tile Tile_61.7994_26.1910 re-downloaded and is now valid.
# Downloaded Tile_61.8494_25.6410
# Tile Tile_61.8494_25.6410 is valid.
# Downloaded Tile_61.8494_25.8910
# Tile Tile_61.8494_25.8910 is valid.
# Downloaded Tile_61.8494_25.9910
# Tile Tile_61.8494_25.9910 is valid.
# Downloaded Tile_61.8994_25.3410
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.8994_25.3410.tif
# Tile Tile_61.8994_25.3410 is invalid, re-downloading...
# Downloaded Tile_61.8494_25.2410
# Tile Tile_61.8494_25.2410 is valid.
# Downloaded Tile_61.8494_28.5410
# Tile Tile_61.8494_28.5410 is valid.
# Downloaded Tile_61.8994_26.0910
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.8994_26.0910.tif
# Tile Tile_61.8994_26.0910 is invalid, re-downloading...
# Downloaded Tile_61.8994_25.1410
# Tile Tile_61.8994_25.1410 is valid.
# Downloaded Tile_61.8494_28.6410
# Tile Tile_61.8494_28.6410 is valid.
# Downloaded Tile_61.8494_29.5410
# Tile Tile_61.8494_29.5410 is valid.
# Downloaded Tile_61.8494_26.1910
# Tile Tile_61.8494_26.1910 is valid.
# Downloaded Tile_61.8994_25.1910
# Tile Tile_61.8994_25.1910 is valid.
# Downloaded Tile_61.8994_25.4410
# Tile Tile_61.8994_25.4410 is valid.
# Downloaded Tile_61.8994_25.7410
# Tile Tile_61.8994_25.7410 is valid.
# Downloaded Tile_61.8994_25.8410
# Tile Tile_61.8994_25.8410 is valid.
# Downloaded Tile_61.8494_26.2410
# Downloaded Tile_61.8994_25.9910
# Tile Tile_61.8994_25.9910 is valid.
# Tile Tile_61.8494_26.2410 is valid.
# Downloaded Tile_61.8994_25.3410
# Tile Tile_61.8994_25.3410 re-downloaded and is now valid.
# Downloaded Tile_61.8994_26.2410
# Tile Tile_61.8994_26.2410 is valid.
# Downloaded Tile_61.8994_29.2410
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.8994_29.2410.tif
# Tile Tile_61.8994_29.2410 is invalid, re-downloading...
# Downloaded Tile_61.8994_28.5410
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_61.8994_28.5410.tif
# Tile Tile_61.8994_28.5410 is invalid, re-downloading...
# Downloaded Tile_61.8994_26.0910
# Tile Tile_61.8994_26.0910 re-downloaded and is now valid.
# Downloaded Tile_61.8994_28.6410
# Tile Tile_61.8994_28.6410 is valid.
# Downloaded Tile_61.8994_29.3910
# Tile Tile_61.8994_29.3910 is valid.
# Downloaded Tile_61.8994_29.3410
# Tile Tile_61.8994_29.3410 is valid.
# Downloaded Tile_61.8994_28.8910
# Tile Tile_61.8994_28.8910 is valid.
# Downloaded Tile_61.8994_28.5410
# Tile Tile_61.8994_28.5410 re-downloaded and is now valid.
# Downloaded Tile_61.8994_28.7410
# Tile Tile_61.8994_28.7410 is valid.
# Downloaded Tile_61.8994_29.4910
# Tile Tile_61.8994_29.4910 is valid.
# Downloaded Tile_61.9494_25.5410
# Tile Tile_61.9494_25.5410 is valid.
# Downloaded Tile_61.9494_25.8910
# Tile Tile_61.9494_25.8910 is valid.
# Downloaded Tile_61.9494_25.0910
# Tile Tile_61.9494_25.0910 is valid.
# Downloaded Tile_61.8994_29.5410
# Tile Tile_61.8994_29.5410 is valid.
# Downloaded Tile_61.9494_28.6910
# Tile Tile_61.9494_28.6910 is valid.
# Downloaded Tile_61.9494_25.4910
# Tile Tile_61.9494_25.4910 is valid.
# Downloaded Tile_61.9494_29.0410
# Tile Tile_61.9494_29.0410 is valid.
# Downloaded Tile_61.9494_25.2410
# Tile Tile_61.9494_25.2410 is valid.
# Downloaded Tile_61.8994_29.2410
# Tile Tile_61.8994_29.2410 re-downloaded and is now valid.
# Downloaded Tile_61.9494_29.4410
# Tile Tile_61.9494_29.4410 is valid.
# Downloaded Tile_61.9494_29.1410
# Tile Tile_61.9494_29.1410 is valid.
# Downloaded Tile_61.9494_28.7910
# Tile Tile_61.9494_28.7910 is valid.
# Downloaded Tile_61.9994_26.0410
# Tile Tile_61.9994_26.0410 is valid.
# Downloaded Tile_61.9994_25.9910
# Tile Tile_61.9994_25.9910 is valid.
# Downloaded Tile_61.9994_25.8410
# Tile Tile_61.9994_25.8410 is valid.
# Downloaded Tile_61.9994_25.6410
# Tile Tile_61.9994_25.6410 is valid.
# Downloaded Tile_61.9494_29.1910
# Tile Tile_61.9494_29.1910 is valid.
# Downloaded Tile_61.9994_25.4910
# Tile Tile_61.9994_25.4910 is valid.
# Downloaded Tile_61.9994_26.2410
# Tile Tile_61.9994_26.2410 is valid.
# Downloaded Tile_61.9994_26.2910
# Tile Tile_61.9994_26.2910 is valid.
# Downloaded Tile_61.9994_28.5410
# Tile Tile_61.9994_28.5410 is valid.
# Downloaded Tile_61.9994_28.5910
# Tile Tile_61.9994_28.5910 is valid.
# Downloaded Tile_61.9994_29.3410
# Tile Tile_61.9994_29.3410 is valid.
# Downloaded Tile_61.9994_26.1910
# Tile Tile_61.9994_26.1910 is valid.
# Downloaded Tile_61.9994_29.1910
# Tile Tile_61.9994_29.1910 is valid.
# Downloaded Tile_61.9994_28.6910
# Tile Tile_61.9994_28.6910 is valid.
# Downloaded Tile_62.0494_28.6410
# Tile Tile_62.0494_28.6410 is valid.
# Downloaded Tile_62.0494_28.7910
# Tile Tile_62.0494_28.7910 is valid.
# Downloaded Tile_62.0994_25.3410
# Tile Tile_62.0994_25.3410 is valid.
# Downloaded Tile_61.9994_28.8410
# Tile Tile_61.9994_28.8410 is valid.
# Downloaded Tile_62.0494_25.5410
# Tile Tile_62.0494_25.5410 is valid.
# Downloaded Tile_62.0994_25.3910
# Tile Tile_62.0994_25.3910 is valid.
# Downloaded Tile_62.0994_29.1910
# Tile Tile_62.0994_29.1910 is valid.
# Downloaded Tile_62.0994_25.9410
# Tile Tile_62.0994_25.9410 is valid.
# Downloaded Tile_62.0994_28.9910
# Tile Tile_62.0994_28.9910 is valid.
# Downloaded Tile_62.0494_25.7410
# Tile Tile_62.0494_25.7410 is valid.
# Downloaded Tile_62.0494_28.8410
# Tile Tile_62.0494_28.8410 is valid.
# Downloaded Tile_62.0994_25.1910
# Tile Tile_62.0994_25.1910 is valid.
# Downloaded Tile_62.0494_25.6410
# Tile Tile_62.0494_25.6410 is valid.
# Downloaded Tile_61.9994_28.4910
# Tile Tile_61.9994_28.4910 is valid.
# Downloaded Tile_62.0994_28.5410
# Tile Tile_62.0994_28.5410 is valid.
# Downloaded Tile_62.0994_29.3410
# Tile Tile_62.0994_29.3410 is valid.
# Downloaded Tile_62.1494_25.4410
# Tile Tile_62.1494_25.4410 is valid.
# Downloaded Tile_62.1494_25.3410
# Tile Tile_62.1494_25.3410 is valid.
# Downloaded Tile_62.1494_25.4910
# Tile Tile_62.1494_25.4910 is valid.
# Downloaded Tile_62.1494_28.4910
# Tile Tile_62.1494_28.4910 is valid.
# Downloaded Tile_62.1494_26.3410
# Tile Tile_62.1494_26.3410 is valid.
# Downloaded Tile_62.1494_25.8910
# Tile Tile_62.1494_25.8910 is valid.
# Downloaded Tile_62.1494_25.9910
# Tile Tile_62.1494_25.9910 is valid.
# Downloaded Tile_62.1494_25.6910
# Tile Tile_62.1494_25.6910 is valid.
# Downloaded Tile_62.1494_28.4410
# Tile Tile_62.1494_28.4410 is valid.
# Downloaded Tile_62.1494_28.5910
# Tile Tile_62.1494_28.5910 is valid.
# Downloaded Tile_62.1494_29.3910
# Tile Tile_62.1494_29.3910 is valid.
# Downloaded Tile_62.1494_25.7410
# Tile Tile_62.1494_25.7410 is valid.
# Downloaded Tile_62.1494_28.8410
# Tile Tile_62.1494_28.8410 is valid.
# Downloaded Tile_62.1494_29.2410
# Tile Tile_62.1494_29.2410 is valid.
# Downloaded Tile_62.1994_28.9410
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_62.1994_28.9410.tif
# Tile Tile_62.1994_28.9410 is invalid, re-downloading...
# Downloaded Tile_62.1994_25.6910
# Tile Tile_62.1994_25.6910 is valid.
# Downloaded Tile_62.1994_28.4410
# Tile Tile_62.1994_28.4410 is valid.
# Downloaded Tile_62.1994_25.9410
# Tile Tile_62.1994_25.9410 is valid.
# Downloaded Tile_62.1994_29.0410
# Tile Tile_62.1994_29.0410 is valid.
# Downloaded Tile_62.1994_25.7410
# Tile Tile_62.1994_25.7410 is valid.
# Downloaded Tile_62.1994_25.8410
# Tile Tile_62.1994_25.8410 is valid.
# Downloaded Tile_62.1994_25.7910
# Tile Tile_62.1994_25.7910 is valid.
# Downloaded Tile_62.1994_29.3910
# Tile Tile_62.1994_29.3910 is valid.
# Downloaded Tile_62.1994_25.2910
# Tile Tile_62.1994_25.2910 is valid.
# Downloaded Tile_62.1994_28.9410
# Tile Tile_62.1994_28.9410 re-downloaded and is now valid.
# Downloaded Tile_62.2494_25.4410
# Tile Tile_62.2494_25.4410 is valid.
# Downloaded Tile_62.2494_25.3410
# Tile Tile_62.2494_25.3410 is valid.
# Downloaded Tile_62.0494_25.2910
# Tile Tile_62.0494_25.2910 is valid.
# Downloaded Tile_62.1994_26.1910
# Tile Tile_62.1994_26.1910 is valid.
# Downloaded Tile_62.2494_25.5410
# Downloaded Tile_62.2494_28.9410
# Tile Tile_62.2494_25.5410 is valid.
# Tile Tile_62.2494_28.9410 is valid.
# Downloaded Tile_62.1494_25.2910
# Tile Tile_62.1494_25.2910 is valid.
# Downloaded Tile_62.2494_25.6910
# Tile Tile_62.2494_25.6910 is valid.
# Downloaded Tile_62.2494_25.2410
# Tile Tile_62.2494_25.2410 is valid.
# Downloaded Tile_62.2494_25.9910
# Tile Tile_62.2494_25.9910 is valid.
# Downloaded Tile_62.2494_25.6410
# Tile Tile_62.2494_25.6410 is valid.
# Downloaded Tile_62.2494_25.8910
# Tile Tile_62.2494_25.8910 is valid.
# Downloaded Tile_62.2494_28.9910
# Tile Tile_62.2494_28.9910 is valid.
# Downloaded Tile_62.2494_29.3410
# Tile Tile_62.2494_29.3410 is valid.
# Downloaded Tile_62.2494_29.1910
# Tile Tile_62.2494_29.1910 is valid.
# Downloaded Tile_62.2494_29.1410
# Tile Tile_62.2494_29.1410 is valid.
# Downloaded Tile_62.2994_25.3910
# Tile Tile_62.2994_25.3910 is valid.
# Downloaded Tile_62.2994_25.6410
# Tile Tile_62.2994_25.6410 is valid.
# Downloaded Tile_62.2994_25.2410
# Tile Tile_62.2994_25.2410 is valid.
# Downloaded Tile_62.2994_28.7410
# Tile Tile_62.2994_28.7410 is valid.
# Downloaded Tile_62.2994_25.7410
# Tile Tile_62.2994_25.7410 is valid.
# Downloaded Tile_62.2994_29.0410
# Tile Tile_62.2994_29.0410 is valid.
# Downloaded Tile_62.2994_29.1910
# Tile Tile_62.2994_29.1910 is valid.
# Downloaded Tile_62.2994_29.2410
# Tile Tile_62.2994_29.2410 is valid.
# Downloaded Tile_62.2994_25.7910
# Tile Tile_62.2994_25.7910 is valid.
# Downloaded Tile_62.2994_26.0410
# Tile Tile_62.2994_26.0410 is valid.
# Downloaded Tile_62.2994_25.2910
# Tile Tile_62.2994_25.2910 is valid.
# Downloaded Tile_62.3494_25.8910
# Tile Tile_62.3494_25.8910 is valid.
# Downloaded Tile_62.2994_26.4910
# Tile Tile_62.2994_26.4910 is valid.
# Downloaded Tile_62.3494_25.5910
# Tile Tile_62.3494_25.5910 is valid.
# Downloaded Tile_62.3494_25.7910
# Tile Tile_62.3494_25.7910 is valid.
# Downloaded Tile_62.3494_28.3910
# Tile Tile_62.3494_28.3910 is valid.
# Downloaded Tile_62.3494_25.9410
# Tile Tile_62.3494_25.9410 is valid.
# Downloaded Tile_62.3494_28.5410
# Tile Tile_62.3494_28.5410 is valid.
# Downloaded Tile_62.3494_28.6910Downloaded Tile_62.3494_28.6410
#
# Tile Tile_62.3494_28.6410 is valid.
# Tile Tile_62.3494_28.6910 is valid.
# Downloaded Tile_62.3494_28.4910
# Tile Tile_62.3494_28.4910 is valid.
# Downloaded Tile_62.3494_29.1910
# Tile Tile_62.3494_29.1910 is valid.
# Downloaded Tile_62.3494_28.9410
# Tile Tile_62.3494_28.9410 is valid.
# Downloaded Tile_62.3494_28.9910
# Tile Tile_62.3494_28.9910 is valid.
# Downloaded Tile_62.3494_28.7910
# Tile Tile_62.3494_28.7910 is valid.
# Downloaded Tile_62.2994_26.2910
# Tile Tile_62.2994_26.2910 is valid.
# Downloaded Tile_62.3494_29.3410
# Tile Tile_62.3494_29.3410 is valid.
# Downloaded Tile_62.3494_28.8410
# Tile Tile_62.3494_28.8410 is valid.
# Downloaded Tile_62.3494_26.0910
# Tile Tile_62.3494_26.0910 is valid.
# Downloaded Tile_62.3994_25.1910
# Tile Tile_62.3994_25.1910 is valid.
# Downloaded Tile_62.3494_29.3910
# Tile Tile_62.3494_29.3910 is valid.
# Downloaded Tile_62.3994_25.6410
# Tile Tile_62.3994_25.6410 is valid.
# Downloaded Tile_62.3994_25.5410
# Tile Tile_62.3994_25.5410 is valid.
# Downloaded Tile_62.3994_25.6910
# Tile Tile_62.3994_25.6910 is valid.
# Downloaded Tile_62.3994_25.3910
# Tile Tile_62.3994_25.3910 is valid.
# Downloaded Tile_62.3994_28.5910
# Tile Tile_62.3994_28.5910 is valid.
# Downloaded Tile_62.3994_25.2410
# Tile Tile_62.3994_25.2410 is valid.
# Downloaded Tile_62.3994_29.2910
# Tile Tile_62.3994_29.2910 is valid.
# Downloaded Tile_62.3994_29.1410
# Tile Tile_62.3994_29.1410 is valid.
# Downloaded Tile_62.3994_29.2410
# Tile Tile_62.3994_29.2410 is valid.
# Downloaded Tile_62.3994_26.2910
# Tile Tile_62.3994_26.2910 is valid.
# Downloaded Tile_62.3994_28.8410
# Tile Tile_62.3994_28.8410 is valid.
# Downloaded Tile_62.3994_25.2910
# Tile Tile_62.3994_25.2910 is valid.
# Downloaded Tile_62.3994_26.2410
# Tile Tile_62.3994_26.2410 is valid.
# Downloaded Tile_62.3994_26.5410
# Downloaded Tile_62.4494_25.3410
# Tile Tile_62.3994_26.5410 is valid.
# Tile Tile_62.4494_25.3410 is valid.
# Downloaded Tile_62.3994_26.1410
# Tile Tile_62.3994_26.1410 is valid.
# Downloaded Tile_62.4494_25.5910
# Tile Tile_62.4494_25.5910 is valid.
# Downloaded Tile_62.4494_25.4910
# Tile Tile_62.4494_25.4910 is valid.
# Downloaded Tile_62.4494_25.6910
# Tile Tile_62.4494_25.6910 is valid.
# Downloaded Tile_62.4494_25.7410
# Tile Tile_62.4494_25.7410 is valid.
# Downloaded Tile_62.4494_25.6410
# Tile Tile_62.4494_25.6410 is valid.
# Downloaded Tile_62.4494_25.8410
# Tile Tile_62.4494_25.8410 is valid.
# Downloaded Tile_62.4494_25.7910
# Tile Tile_62.4494_25.7910 is valid.
# Downloaded Tile_62.4494_25.9410
# Tile Tile_62.4494_25.9410 is valid.
# Downloaded Tile_62.4494_28.9910
# Tile Tile_62.4494_28.9910 is valid.
# Downloaded Tile_62.4494_28.4410
# Tile Tile_62.4494_28.4410 is valid.
# Downloaded Tile_62.4494_29.0410
# Tile Tile_62.4494_29.0410 is valid.
# Downloaded Tile_62.4494_28.4910
# Tile Tile_62.4494_28.4910 is valid.
# Downloaded Tile_62.4494_26.2910
# Tile Tile_62.4494_26.2910 is valid.
# Downloaded Tile_62.4994_25.3910
# Tile Tile_62.4994_25.3910 is valid.
# Downloaded Tile_62.4494_29.2410
# Tile Tile_62.4494_29.2410 is valid.
# Downloaded Tile_62.4994_25.6410
# Tile Tile_62.4994_25.6410 is valid.
# Downloaded Tile_62.4994_25.8410
# Tile Tile_62.4994_25.8410 is valid.
# Downloaded Tile_62.4494_26.1410
# Tile Tile_62.4494_26.1410 is valid.
# Downloaded Tile_62.4994_25.5410
# Tile Tile_62.4994_25.5410 is valid.
# Downloaded Tile_62.4994_25.7910
# Tile Tile_62.4994_25.7910 is valid.
# Downloaded Tile_62.4994_25.7410
# Tile Tile_62.4994_25.7410 is valid.
# Downloaded Tile_62.4994_26.4410
# Tile Tile_62.4994_26.4410 is valid.
# Downloaded Tile_62.4994_26.0910
# Tile Tile_62.4994_26.0910 is valid.
# Downloaded Tile_62.4994_26.2910
# Tile Tile_62.4994_26.2910 is valid.
# Downloaded Tile_62.4994_26.2410
# Tile Tile_62.4994_26.2410 is valid.
# Downloaded Tile_62.4494_26.2410
# Tile Tile_62.4494_26.2410 is valid.
# Downloaded Tile_62.4994_28.4410
# Tile Tile_62.4994_28.4410 is valid.
# Downloaded Tile_62.4994_28.3410
# Tile Tile_62.4994_28.3410 is valid.
# Downloaded Tile_62.4994_28.5910
# Tile Tile_62.4994_28.5910 is valid.
# Downloaded Tile_62.4994_26.5410
# Tile Tile_62.4994_26.5410 is valid.
# Downloaded Tile_62.4994_28.9910
# Downloaded Tile_62.4994_26.1410
# Tile Tile_62.4994_28.9910 is valid.
# Tile Tile_62.4994_26.1410 is valid.
# Downloaded Tile_62.4994_28.6410
# Tile Tile_62.4994_28.6410 is valid.
# Downloaded Tile_62.4994_28.6910
# Tile Tile_62.4994_28.6910 is valid.
# Downloaded Tile_62.4994_29.0410
# Tile Tile_62.4994_29.0410 is valid.
# Downloaded Tile_62.4994_29.1410
# Tile Tile_62.4994_29.1410 is valid.
# Downloaded Tile_62.4994_29.2910
# Tile Tile_62.4994_29.2910 is valid.
# Downloaded Tile_62.5494_25.3910
# Tile Tile_62.5494_25.3910 is valid.
# Downloaded Tile_62.4994_28.8410
# Tile Tile_62.4994_28.8410 is valid.
# Downloaded Tile_62.5494_25.4910
# Tile Tile_62.5494_25.4910 is valid.
# Downloaded Tile_62.5494_25.2410
# Tile Tile_62.5494_25.2410 is valid.
# Downloaded Tile_62.5494_26.0410
# Tile Tile_62.5494_26.0410 is valid.
# Downloaded Tile_62.5494_25.5410
# Tile Tile_62.5494_25.5410 is valid.
# Downloaded Tile_62.5494_25.2910
# Tile Tile_62.5494_25.2910 is valid.
# Downloaded Tile_62.5494_28.6910
# Tile Tile_62.5494_28.6910 is valid.
# Downloaded Tile_62.5494_28.3910
# Tile Tile_62.5494_28.3910 is valid.
# Downloaded Tile_62.5494_28.5410
# Tile Tile_62.5494_28.5410 is valid.
# Downloaded Tile_62.5994_25.3410
# Tile Tile_62.5994_25.3410 is valid.
# Downloaded Tile_62.5494_28.3410
# Tile Tile_62.5494_28.3410 is valid.
# Downloaded Tile_62.5494_26.4910
# Tile Tile_62.5494_26.4910 is valid.
# Downloaded Tile_62.5994_25.5910
# Tile Tile_62.5994_25.5910 is valid.
# Downloaded Tile_62.5994_25.2410
# Tile Tile_62.5994_25.2410 is valid.
# Downloaded Tile_62.5994_25.6410
# Tile Tile_62.5994_25.6410 is valid.
# Downloaded Tile_62.5494_28.8410
# Tile Tile_62.5494_28.8410 is valid.
# Downloaded Tile_62.5494_26.1910
# Tile Tile_62.5494_26.1910 is valid.
# Downloaded Tile_62.5994_25.5410
# Tile Tile_62.5994_25.5410 is valid.
# Downloaded Tile_62.5994_25.8910
# Tile Tile_62.5994_25.8910 is valid.
# Downloaded Tile_62.5994_28.3910
# Tile Tile_62.5994_28.3910 is valid.
# Downloaded Tile_62.5994_28.3410
# Tile Tile_62.5994_28.3410 is valid.
# Downloaded Tile_62.5994_28.2910
# Tile Tile_62.5994_28.2910 is valid.
# Downloaded Tile_62.5994_26.0910
# Tile Tile_62.5994_26.0910 is valid.
# Downloaded Tile_62.5994_28.4910
# Tile Tile_62.5994_28.4910 is valid.
# Downloaded Tile_62.5994_26.2910
# Tile Tile_62.5994_26.2910 is valid.
# Downloaded Tile_62.5994_26.3910
# Tile Tile_62.5994_26.3910 is valid.
# Downloaded Tile_62.5994_28.7410
# Tile Tile_62.5994_28.7410 is valid.
# Downloaded Tile_62.5994_26.3410
# Tile Tile_62.5994_26.3410 is valid.
# Downloaded Tile_62.5994_26.1410
# Tile Tile_62.5994_26.1410 is valid.
# Downloaded Tile_62.5994_26.4910
# Tile Tile_62.5994_26.4910 is valid.
# Downloaded Tile_62.5994_28.7910
# Tile Tile_62.5994_28.7910 is valid.
# Downloaded Tile_62.5994_26.5410
# Tile Tile_62.5994_26.5410 is valid.
# Downloaded Tile_62.5994_28.8410
# Tile Tile_62.5994_28.8410 is valid.
# Downloaded Tile_62.5994_26.4410
# Tile Tile_62.5994_26.4410 is valid.
# Downloaded Tile_62.5994_29.0910
# Tile Tile_62.5994_29.0910 is valid.
# Downloaded Tile_62.5994_29.2410
# Tile Tile_62.5994_29.2410 is valid.
# Downloaded Tile_62.6494_25.5910
# Tile Tile_62.6494_25.5910 is valid.
# Downloaded Tile_62.5994_28.8910
# Tile Tile_62.5994_28.8910 is valid.
# Downloaded Tile_62.5994_28.9410
# Tile Tile_62.5994_28.9410 is valid.
# Downloaded Tile_62.5994_29.2910
# Tile Tile_62.5994_29.2910 is valid.
# Downloaded Tile_62.6494_25.4910
# Tile Tile_62.6494_25.4910 is valid.
# Downloaded Tile_62.6494_25.5410
# Tile Tile_62.6494_25.5410 is valid.
# Downloaded Tile_62.5994_29.1410
# Tile Tile_62.5994_29.1410 is valid.
# Downloaded Tile_62.5994_29.3410
# Tile Tile_62.5994_29.3410 is valid.
# Downloaded Tile_62.6494_25.2410
# Tile Tile_62.6494_25.2410 is valid.
# Downloaded Tile_62.6494_25.6410
# Tile Tile_62.6494_25.6410 is valid.
# Downloaded Tile_62.6494_25.6910
# Tile Tile_62.6494_25.6910 is valid.
# Downloaded Tile_62.6494_25.7910
# Tile Tile_62.6494_25.7910 is valid.
# Downloaded Tile_62.6494_25.8910
# Tile Tile_62.6494_25.8910 is valid.
# Downloaded Tile_62.6494_26.4410
# File is too small: /home/rishabh.mondal/Brick-Kilns-project/ijcai_2025_kilns/raw_data/setinel_tiles/balochistan/Tile_62.6494_26.4410.tif
# Tile Tile_62.6494_26.4410 is invalid, re-downloading...
# Downloaded Tile_62.6494_28.3410
# Tile Tile_62.6494_28.3410 is valid.
# Downloaded Tile_62.6494_28.6910
# Tile Tile_62.6494_28.6910 is valid.
# Downloaded Tile_62.6494_28.3910
# Tile Tile_62.6494_28.3910 is valid.
# Downloaded Tile_62.6494_28.4410
# Tile Tile_62.6494_28.4410 is valid.
# Downloaded Tile_62.6494_26.3410
# Tile Tile_62.6494_26.3410 is valid.
# Downloaded Tile_62.6494_26.0910
# Tile Tile_62.6494_26.0910 is valid.
# Downloaded Tile_62.6494_25.9410
# Tile Tile_62.6494_25.9410 is valid.
# Downloaded Tile_62.6494_26.4910
# Tile Tile_62.6494_26.4910 is valid.
# Downloaded Tile_62.6494_28.7910
# Tile Tile_62.6494_28.7910 is valid.
# Downloaded Tile_62.6494_28.4910
# Tile Tile_62.6494_28.4910 is valid.
# Downloaded Tile_62.6494_26.2410
# Tile Tile_62.6494_26.2410 is valid.
# Downloaded Tile_62.6494_26.4410
# Tile Tile_62.6494_26.4410 re-downloaded and is now valid.
# Downloaded Tile_62.6494_28.9910
# Tile Tile_62.6494_28.9910 is valid.
# Downloaded Tile_62.6494_26.5410
# Tile Tile_62.6494_26.5410 is valid.
# Downloaded Tile_62.6494_26.1410
# Tile Tile_62.6494_26.1410 is valid.
# Downloaded Tile_62.6494_28.8410
# Tile Tile_62.6494_28.8410 is valid.
# Downloaded Tile_62.6994_25.5910
# Tile Tile_62.6994_25.5910 is valid.
# Downloaded Tile_62.6494_29.2410
# Tile Tile_62.6494_29.2410 is valid.
# Downloaded Tile_62.6494_29.0910
# Tile Tile_62.6494_29.0910 is valid.
# Downloaded Tile_62.6994_25.7410
# Tile Tile_62.6994_25.7410 is valid.
# Downloaded Tile_62.6994_25.6410
# Tile Tile_62.6994_25.6410 is valid.
# Downloaded Tile_62.6494_29.3910
# Tile Tile_62.6494_29.3910 is valid.
# Downloaded Tile_62.6994_25.2410
# Tile Tile_62.6994_25.2410 is valid.
# Downloaded Tile_62.6994_26.0410
# Tile Tile_62.6994_26.0410 is valid.
# Downloaded Tile_62.6994_25.3910
# Tile Tile_62.6994_25.3910 is valid.
# Downloaded Tile_62.6994_28.3410
# Tile Tile_62.6994_28.3410 is valid.
# Downloaded Tile_62.6994_26.4410
# Tile Tile_62.6994_26.4410 is valid.
# Downloaded Tile_62.6994_26.0910
# Tile Tile_62.6994_26.0910 is valid.
# Downloaded Tile_62.6994_28.5910
# Tile Tile_62.6994_28.5910 is valid.
# Downloaded Tile_62.6994_28.5410
# Tile Tile_62.6994_28.5410 is valid.
# Downloaded Tile_62.6994_26.1910
# Tile Tile_62.6994_26.1910 is valid.
# Downloaded Tile_62.7494_25.3410
# Tile Tile_62.7494_25.3410 is valid.
# Downloaded Tile_62.6994_28.6910
# Tile Tile_62.6994_28.6910 is valid.
# Downloaded Tile_62.7494_25.5910
# Tile Tile_62.7494_25.5910 is valid.
# Downloaded Tile_62.6994_29.1910
# Tile Tile_62.6994_29.1910 is valid.
# Downloaded Tile_62.6994_26.2410
# Tile Tile_62.6994_26.2410 is valid.
# Downloaded Tile_62.7494_25.6410
# Tile Tile_62.7494_25.6410 is valid.
# Downloaded Tile_62.6994_28.9410
# Tile Tile_62.6994_28.9410 is valid.
# Downloaded Tile_62.6994_28.6410
# Tile Tile_62.6994_28.6410 is valid.
# Downloaded Tile_62.7494_25.7410
# Tile Tile_62.7494_25.7410 is valid.
# Downloaded Tile_62.6994_28.8910
# Tile Tile_62.6994_28.8910 is valid.
# Downloaded Tile_62.7494_25.9910
# Tile Tile_62.7494_25.9910 is valid.
# Downloaded Tile_62.7494_26.0410
# Tile Tile_62.7494_26.0410 is valid.
# Downloaded Tile_62.7494_26.1910
# Tile Tile_62.7494_26.1910 is valid.
# Downloaded Tile_62.7494_26.4910
# Tile Tile_62.7494_26.4910 is valid.
# Downloaded Tile_62.7494_26.6410
# Tile Tile_62.7494_26.6410 is valid.
# Downloaded Tile_62.7494_28.6410
# Tile Tile_62.7494_28.6410 is valid.
# Downloaded Tile_62.7494_28.1910
# Tile Tile_62.7494_28.1910 is valid.
# Downloaded Tile_62.7494_28.0410
# Tile Tile_62.7494_28.0410 is valid.
# Downloaded Tile_62.7494_28.7410
# Tile Tile_62.7494_28.7410 is valid.
# Downloaded Tile_62.7494_27.2410
# Tile Tile_62.7494_27.2410 is valid.
# Downloaded Tile_62.7494_29.1410
# Tile Tile_62.7494_29.1410 is valid.
# Downloaded Tile_62.7494_28.3910
# Tile Tile_62.7494_28.3910 is valid.
# Downloaded Tile_62.7494_28.4910
# Tile Tile_62.7494_28.4910 is valid.
# Downloaded Tile_62.7494_29.1910
# Tile Tile_62.7494_29.1910 is valid.
# Downloaded Tile_62.7494_29.2410
# Tile Tile_62.7494_29.2410 is valid.
# Downloaded Tile_62.7494_28.8910
# Tile Tile_62.7494_28.8910 is valid.
# Downloaded Tile_62.7994_25.3910
# Tile Tile_62.7994_25.3910 is valid.
# Downloaded Tile_62.7994_25.4410
# Tile Tile_62.7994_25.4410 is valid.
# Downloaded Tile_62.7494_28.4410
# Tile Tile_62.7494_28.4410 is valid.
# Downloaded Tile_62.7994_25.6410
# Tile Tile_62.7994_25.6410 is valid.
# Downloaded Tile_62.7994_25.8910
# Tile Tile_62.7994_25.8910 is valid.
# Downloaded Tile_62.7994_25.4910
# Tile Tile_62.7994_25.4910 is valid.
# Downloaded Tile_62.7994_25.5410
# Tile Tile_62.7994_25.5410 is valid.
# Downloaded Tile_62.7994_25.8410
# Tile Tile_62.7994_25.8410 is valid.
# Downloaded Tile_62.7994_25.5910
# Tile Tile_62.7994_25.5910 is valid.
# Downloaded Tile_62.7994_26.0910
# Tile Tile_62.7994_26.0910 is valid.
# Downloaded Tile_62.7994_27.2410
# Tile Tile_62.7994_27.2410 is valid.
# Downloaded Tile_62.7994_27.7910
# Tile Tile_62.7994_27.7910 is valid.
# Downloaded Tile_62.7494_27.9410
# Tile Tile_62.7494_27.9410 is valid.
# Downloaded Tile_62.7994_27.7410
# Tile Tile_62.7994_27.7410 is valid.
# Downloaded Tile_62.8494_25.3410
# Tile Tile_62.8494_25.3410 is valid.
# Downloaded Tile_62.7994_27.5910
# Tile Tile_62.7994_27.5910 is valid.
# Downloaded Tile_62.7994_26.5910
# Tile Tile_62.7994_26.5910 is valid.
# Downloaded Tile_62.8494_25.5910
# Tile Tile_62.8494_25.5910 is valid.
# Downloaded Tile_62.7994_28.3910
# Tile Tile_62.7994_28.3910 is valid.
# Downloaded Tile_62.7994_29.0910
# Tile Tile_62.7994_29.0910 is valid.
# Downloaded Tile_62.7994_27.8910
# Tile Tile_62.7994_27.8910 is valid.
# Downloaded Tile_62.8494_25.6910
# Tile Tile_62.8494_25.6910 is valid.
# Downloaded Tile_62.7994_28.1910
# Tile Tile_62.7994_28.1910 is valid.
# Downloaded Tile_62.7994_28.5910
# Tile Tile_62.7994_28.5910 is valid.
# Downloaded Tile_62.8494_26.0410
# Tile Tile_62.8494_26.0410 is valid.
# Downloaded Tile_62.7994_28.6410
# Tile Tile_62.7994_28.6410 is valid.
# Downloaded Tile_62.8494_26.3910
# Tile Tile_62.8494_26.3910 is valid.
# Downloaded Tile_62.8494_26.1410
# Tile Tile_62.8494_26.1410 is valid.
# Downloaded Tile_62.8494_26.1910
# Tile Tile_62.8494_26.1910 is valid.
# Downloaded Tile_62.8494_26.6410
# Tile Tile_62.8494_26.6410 is valid.
# Downloaded Tile_62.8494_27.7410
# Tile Tile_62.8494_27.7410 is valid.
# Downloaded Tile_62.8494_27.2910
# Tile Tile_62.8494_27.2910 is valid.
# Downloaded Tile_62.8494_28.2410
# Tile Tile_62.8494_28.2410 is valid.
# Downloaded Tile_62.8494_27.1910
# Tile Tile_62.8494_27.1910 is valid.
# Downloaded Tile_62.8494_27.3410
# Tile Tile_62.8494_27.3410 is valid.
# Downloaded Tile_62.8494_28.1410
# Tile Tile_62.8494_28.1410 is valid.
# Downloaded Tile_62.8494_28.5410
# Tile Tile_62.8494_28.5410 is valid.
# Downloaded Tile_62.8494_28.1910
# Tile Tile_62.8494_28.1910 is valid.
# Downloaded Tile_62.8494_28.4910
# Tile Tile_62.8494_28.4910 is valid.
# Downloaded Tile_62.8494_27.9910
# Tile Tile_62.8494_27.9910 is valid.
# Downloaded Tile_62.8494_28.5910
# Tile Tile_62.8494_28.5910 is valid.
# Downloaded Tile_62.8494_29.2910
# Tile Tile_62.8494_29.2910 is valid.
# Downloaded Tile_62.8494_29.3910
# Tile Tile_62.8494_29.3910 is valid.
# Downloaded Tile_62.8994_25.2410
# Tile Tile_62.8994_25.2410 is valid.
# Downloaded Tile_62.8494_28.9410
# Tile Tile_62.8494_28.9410 is valid.
# Downloaded Tile_62.8994_25.3410
# Tile Tile_62.8994_25.3410 is valid.
# Downloaded Tile_62.8994_25.2910
# Tile Tile_62.8994_25.2910 is valid.
# Downloaded Tile_62.8994_25.3910
# Tile Tile_62.8994_25.3910 is valid.
# Downloaded Tile_62.8994_25.4410
# Tile Tile_62.8994_25.4410 is valid.
# Downloaded Tile_62.8494_28.8410
# Tile Tile_62.8494_28.8410 is valid.
# Downloaded Tile_62.8994_25.5910
# Tile Tile_62.8994_25.5910 is valid.
# Downloaded Tile_62.8994_25.4910
# Tile Tile_62.8994_25.4910 is valid.
# Downloaded Tile_62.8994_25.6410
# Tile Tile_62.8994_25.6410 is valid.
# Downloaded Tile_62.8994_25.8910
# Tile Tile_62.8994_25.8910 is valid.
# Downloaded Tile_62.8994_26.3910
# Tile Tile_62.8994_26.3910 is valid.
# Downloaded Tile_62.8494_28.8910
# Tile Tile_62.8494_28.8910 is valid.
# Downloaded Tile_62.8994_26.2910
# Tile Tile_62.8994_26.2910 is valid.
# Downloaded Tile_62.8994_26.4410
# Tile Tile_62.8994_26.4410 is valid.
# Downloaded Tile_62.8994_26.5410
# Tile Tile_62.8994_26.5410 is valid.
# Downloaded Tile_62.8994_26.6410
# Tile Tile_62.8994_26.6410 is valid.
# Downloaded Tile_62.8994_26.5910
# Tile Tile_62.8994_26.5910 is valid.
# Downloaded Tile_62.8994_27.3910
# Tile Tile_62.8994_27.3910 is valid.
# Downloaded Tile_62.8994_27.3410
# Tile Tile_62.8994_27.3410 is valid.
# Downloaded Tile_62.8994_28.5410
# Tile Tile_62.8994_28.5410 is valid.
# Downloaded Tile_62.9494_25.2410
# Tile Tile_62.9494_25.2410 is valid.
# Downloaded Tile_62.8994_28.6910
# Tile Tile_62.8994_28.6910 is valid.
# Downloaded Tile_62.8994_28.0910
# Tile Tile_62.8994_28.0910 is valid.
# Downloaded Tile_62.8994_27.5410
# Tile Tile_62.8994_27.5410 is valid.
# Downloaded Tile_62.9494_25.6410
# Tile Tile_62.9494_25.6410 is valid.
# Downloaded Tile_62.9494_25.2910
# Tile Tile_62.9494_25.2910 is valid.
# Downloaded Tile_62.8994_28.6410
# Tile Tile_62.8994_28.6410 is valid.
# Downloaded Tile_62.9494_25.6910
# Downloaded Tile_62.8994_28.0410
# Tile Tile_62.9494_25.6910 is valid.
# Tile Tile_62.8994_28.0410 is valid.
# Downloaded Tile_62.8994_28.3410
# Tile Tile_62.8994_28.3410 is valid.
# Downloaded Tile_62.9494_25.9410
# Tile Tile_62.9494_25.9410 is valid.
# Downloaded Tile_62.8994_28.9410
# Tile Tile_62.8994_28.9410 is valid.
# Downloaded Tile_62.8994_28.7410
# Tile Tile_62.8994_28.7410 is valid.
# Downloaded Tile_62.9494_26.1910
# Tile Tile_62.9494_26.1910 is valid.
# Downloaded Tile_62.9494_26.4410
# Tile Tile_62.9494_26.4410 is valid.
# Downloaded Tile_62.9494_26.2410
# Tile Tile_62.9494_26.2410 is valid.
# Downloaded Tile_62.9494_26.5910
# Tile Tile_62.9494_26.5910 is valid.
# Downloaded Tile_62.9494_26.5410
# Tile Tile_62.9494_26.5410 is valid.
# Downloaded Tile_62.9494_27.3910
# Tile Tile_62.9494_27.3910 is valid.
# Downloaded Tile_62.9494_26.4910
# Tile Tile_62.9494_26.4910 is valid.
# Downloaded Tile_62.9494_27.1910
# Tile Tile_62.9494_27.1910 is valid.
# Downloaded Tile_62.9494_26.0910
# Tile Tile_62.9494_26.0910 is valid.
# Downloaded Tile_62.9494_28.3910
# Tile Tile_62.9494_28.3910 is valid.
# Downloaded Tile_62.9494_27.4910
# Tile Tile_62.9494_27.4910 is valid.
# Downloaded Tile_62.9494_28.1410
# Tile Tile_62.9494_28.1410 is valid.
# Downloaded Tile_62.9494_28.4410
# Tile Tile_62.9494_28.4410 is valid.
# Downloaded Tile_62.9494_28.5410
# Tile Tile_62.9494_28.5410 is valid.
# Downloaded Tile_62.9494_27.4410
# Tile Tile_62.9494_27.4410 is valid.
# Downloaded Tile_62.9494_27.9910
# Tile Tile_62.9494_27.9910 is valid.
# Downloaded Tile_62.9494_28.6910
# Tile Tile_62.9494_28.6910 is valid.
# Downloaded Tile_62.9494_28.7410
# Tile Tile_62.9494_28.7410 is valid.
# Downloaded Tile_62.9494_29.1410
# Tile Tile_62.9494_29.1410 is valid.
# Downloaded Tile_62.9494_29.0410
# Tile Tile_62.9494_29.0410 is valid.
# Downloaded Tile_62.9994_25.8410
# Tile Tile_62.9994_25.8410 is valid.
# Downloaded Tile_62.9494_28.8910
# Tile Tile_62.9494_28.8910 is valid.
# Downloaded Tile_62.9994_25.9910
# Tile Tile_62.9994_25.9910 is valid.
# Downloaded Tile_62.9494_29.0910
# Tile Tile_62.9494_29.0910 is valid.
# Downloaded Tile_62.9994_25.7410
# Tile Tile_62.9994_25.7410 is valid.
# Downloaded Tile_62.9994_25.2910
# Tile Tile_62.9994_25.2910 is valid.
# Downloaded Tile_62.9994_25.3410
# Tile Tile_62.9994_25.3410 is valid.
# Downloaded Tile_62.9994_25.7910
# Tile Tile_62.9994_25.7910 is valid.
# Downloaded Tile_62.9494_29.2410
# Tile Tile_62.9494_29.2410 is valid.
# Downloaded Tile_62.9994_26.0410
# Tile Tile_62.9994_26.0410 is valid.
# Downloaded Tile_62.9994_26.0910
# Tile Tile_62.9994_26.0910 is valid.
# Downloaded Tile_62.9994_26.5410
# Tile Tile_62.9994_26.5410 is valid.
# Downloaded Tile_62.9994_26.2910
# Tile Tile_62.9994_26.2910 is valid.
# Downloaded Tile_62.9994_27.2410
# Tile Tile_62.9994_27.2410 is valid.
# Downloaded Tile_62.9994_28.0410
# Tile Tile_62.9994_28.0410 is valid.
# Downloaded Tile_62.9994_27.5410
# Tile Tile_62.9994_27.5410 is valid.
# Downloaded Tile_62.9994_28.4410
# Tile Tile_62.9994_28.4410 is valid.
# Downloaded Tile_62.9994_28.5910
# Tile Tile_62.9994_28.5910 is valid.
# Downloaded Tile_62.9994_28.0910
# Tile Tile_62.9994_28.0910 is valid.
# Downloaded Tile_62.9994_27.8410
# Tile Tile_62.9994_27.8410 is valid.
# Downloaded Tile_62.9994_27.7410
# Tile Tile_62.9994_27.7410 is valid.
# Downloaded Tile_62.9994_28.2410
# Tile Tile_62.9994_28.2410 is valid.
# Downloaded Tile_62.9994_28.4910
# Tile Tile_62.9994_28.4910 is valid.
# Downloaded Tile_62.9994_28.6910
# Tile Tile_62.9994_28.6910 is valid.
# Downloaded Tile_63.0494_25.4410
# Tile Tile_63.0494_25.4410 is valid.
# Downloaded Tile_62.9994_29.1910
# Tile Tile_62.9994_29.1910 is valid.
# Downloaded Tile_63.0494_25.2910
# Tile Tile_63.0494_25.2910 is valid.
# Downloaded Tile_62.9994_29.1410
# Tile Tile_62.9994_29.1410 is valid.
# Downloaded Tile_62.9994_27.8910
# Tile Tile_62.9994_27.8910 is valid.
# Downloaded Tile_63.0494_25.4910
# Tile Tile_63.0494_25.4910 is valid.
# Downloaded Tile_63.0494_25.5410
# Tile Tile_63.0494_25.5410 is valid.
# Downloaded Tile_63.0494_25.6910
# Tile Tile_63.0494_25.6910 is valid.
# Downloaded Tile_62.9994_27.9410
# Tile Tile_62.9994_27.9410 is valid.
# Downloaded Tile_63.0494_25.7410
# Tile Tile_63.0494_25.7410 is valid.
# Downloaded Tile_63.0494_25.5910
# Tile Tile_63.0494_25.5910 is valid.
# Downloaded Tile_63.0494_26.2410
# Tile Tile_63.0494_26.2410 is valid.
# Downloaded Tile_62.9994_28.8910
# Tile Tile_62.9994_28.8910 is valid.
# Downloaded Tile_63.0494_27.1910
# Tile Tile_63.0494_27.1910 is valid.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 282
#     276 def process_tiles_parallel(filtered_tiles_gdf, save_path, n_jobs=4):
#     277     Parallel(n_jobs=n_jobs)(
#     278         delayed(download_and_validate_tile)(
#     279             row.geometry, row.tile_name, save_path
#     280         ) for _, row in filtered_tiles_gdf.iterrows()
#     281     )
# --> 282 process_tiles_parallel(filtered_tiles_gdf, save_path, n_jobs=16)
#     284 print("All tiles processed.")
#     285 # Run the tile processing
#     286 # process_tiles_sequentially(filtered_tiles_gdf, save_path)
#
# Cell In[10], line 277, in process_tiles_parallel(filtered_tiles_gdf, save_path, n_jobs)
#     276 def process_tiles_parallel(filtered_tiles_gdf, save_path, n_jobs=4):
# --> 277     Parallel(n_jobs=n_jobs)(
#     278         delayed(download_and_validate_tile)(
#     279             row.geometry, row.tile_name, save_path
#     280         ) for _, row in filtered_tiles_gdf.iterrows()
#     281     )
#
# File ~/.local/lib/python3.12/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~/.local/lib/python3.12/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~/.local/lib/python3.12/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:
